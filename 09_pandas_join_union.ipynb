# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Pandas_dataengineer_notes/blob/main/09_pandas_join_union.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
! wget https://github.com/erkansirin78/datasets/raw/refs/heads/master/retail_db/order_items.csv
# Out:
# --2026-03-21 15:03:50--  https://github.com/erkansirin78/datasets/raw/refs/heads/master/retail_db/order_items.csv
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/erkansirin78/datasets/refs/heads/master/retail_db/order_items.csv [following]
# --2026-03-21 15:03:51--  https://raw.githubusercontent.com/erkansirin78/datasets/refs/heads/master/retail_db/order_items.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5408988 (5.2M) [text/plain]
# Saving to: ‘order_items.csv’
#
# order_items.csv     100%[===================>]   5.16M  --.-KB/s    in 0.08s
#
# ...

# %%
! wget https://github.com/erkansirin78/datasets/raw/refs/heads/master/retail_db/products.csv
# Out:
# --2026-03-21 15:04:47--  https://github.com/erkansirin78/datasets/raw/refs/heads/master/retail_db/products.csv
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/erkansirin78/datasets/refs/heads/master/retail_db/products.csv [following]
# --2026-03-21 15:04:47--  https://raw.githubusercontent.com/erkansirin78/datasets/refs/heads/master/retail_db/products.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 174196 (170K) [text/plain]
# Saving to: ‘products.csv’
#
# products.csv        100%[===================>] 170.11K  --.-KB/s    in 0.03s
#
# ...

# %%
order_items = pd.read_csv('order_items.csv')

# %%
products = pd.read_csv("products.csv")

# %% [markdown]
# Let's first inspect rows in the `outer_join` where data from `order_items` is missing, indicating they originated only from the `products` table and had no corresponding `orderItemProductId` in `order_items`.

# %%
missing_order_items_data = outer_join[outer_join['orderItemName'].isna()]
display(missing_order_items_data.head())

# %% [markdown]
# Now, let's inspect rows in the `outer_join` where data from `products` is missing, indicating they originated only from the `order_items` table and had no corresponding `productId` in `products`.

# %%
missing_products_data = outer_join[outer_join['productName'].isna()]
display(missing_products_data.head())

# %%
order_items.head()
# Out:
#    orderItemName  orderItemOrderId  orderItemProductId  orderItemQuantity  \
# 0              1                 1                 957                  1
# 1              2                 2                1073                  1
# 2              3                 2                 502                  5
# 3              4                 2                 403                  1
# 4              5                 4                 897                  2
#
#    orderItemSubTotal  orderItemProductPrice
# 0             299.98                 299.98
# 1             199.99                 199.99
# 2             250.00                  50.00
# 3             129.99                 129.99
# 4              49.98                  24.99

# %%
products.head()
# Out:
#    productId  productCategoryId  \
# 0          1                  2
# 1          2                  2
# 2          3                  2
# 3          4                  2
# 4          5                  2
#
#                                      productName  productDescription  \
# 0  Quest Q64 10 FT. x 10 FT. Slant Leg Instant U                 NaN
# 1  Under Armour Men's Highlight MC Football Clea                 NaN
# 2  Under Armour Men's Renegade D Mid Football Cl                 NaN
# 3  Under Armour Men's Renegade D Mid Football Cl                 NaN
# 4  Riddell Youth Revolution Speed Custom Footbal                 NaN
#
#    productPrice                                       productImage
# 0         59.98  http://images.acmesports.sports/Quest+Q64+10+F...
# 1        129.99  http://images.acmesports.sports/Under+Armour+M...
# 2         89.99  http://images.acmesports.sports/Under+Armour+M...
# 3         89.99  http://images.acmesports.sports/Under+Armour+M...
# ...

# %%
#Union two dataframe with concatenate
products.shape
# Out:
# (1345, 6)

# %%
union_products = pd.concat([products, products])
union_products.shape
# Out:
# (2690, 6)

# %%
#inner join two dataframe with merge
inner_join = pd.merge(order_items,products, left_on="orderItemProductId", right_on ="productId")
inner_join.head()
# Out:
#    orderItemName  orderItemOrderId  orderItemProductId  orderItemQuantity  \
# 0              1                 1                 957                  1
# 1              2                 2                1073                  1
# 2              3                 2                 502                  5
# 3              4                 2                 403                  1
# 4              5                 4                 897                  2
#
#    orderItemSubTotal  orderItemProductPrice  productId  productCategoryId  \
# 0             299.98                 299.98        957                 43
# 1             199.99                 199.99       1073                 48
# 2             250.00                  50.00        502                 24
# 3             129.99                 129.99        403                 18
# 4              49.98                  24.99        897                 40
#
#                                      productName  productDescription  \
# ...

# %%
#outer join two dataframes
outer_join = pd.merge(order_items,products,left_on = "orderItemProductId", right_on = "productId", how="outer")

# %%
outer_join.head(50)
# Out:
#     orderItemName  orderItemOrderId  orderItemProductId  orderItemQuantity  \
# 0             NaN               NaN                 NaN                NaN
# 1             NaN               NaN                 NaN                NaN
# 2             NaN               NaN                 NaN                NaN
# 3             NaN               NaN                 NaN                NaN
# 4             NaN               NaN                 NaN                NaN
# 5             NaN               NaN                 NaN                NaN
# 6             NaN               NaN                 NaN                NaN
# 7             NaN               NaN                 NaN                NaN
# 8             NaN               NaN                 NaN                NaN
# 9             NaN               NaN                 NaN                NaN
# 10            NaN               NaN                 NaN                NaN
# ...
